# %% [markdown]
# <a href="https://colab.research.google.com/github/mabel1199/Tarea1labE/blob/main/Copia_de_Tarea_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea 1

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import matplotlib.colors as mcolors

# %% [markdown]
# ### Ejemplo 1

# %%
# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Color personalizado en hexadecimal
hex_color = "#AE57FA"  # morado

# Crear gráfica
plt.figure(figsize=(6, 4))
plt.plot(x, y, marker='o', color=hex_color, linewidth=2, label=f"Color {hex_color}")
plt.title("Gráfica con color hexadecimal personalizado: Morado")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.legend()
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# #### Ejemplo 2

# %%
def generate_random_hex_color():
    return "#{:06X}".format(random.randint(0, 0xFFFFFF))

# Generar 5 colores aleatorios
colors = [generate_random_hex_color() for _ in range(5)]

# Graficar como barras de colores
plt.figure(figsize=(8, 4))
for i, color in enumerate(colors):
    plt.bar(i, 1, color=color)
    plt.text(i, 1.05, color, ha='center', va='bottom', fontsize=10)

plt.xticks([])
plt.yticks([])
plt.title("5 Colores Aleatorios en Hexadecimal")
plt.xlim(-0.5, 4.5)
plt.ylim(0, 1.1)
plt.tight_layout()

# %% [markdown]
# Ejemplo de uso de codificacion hexadecimal del color , se quiere representar la distribución de temperatura en una placa usando colores, internamente, matplotlib traduce cada valor numérico a un código RGB/hex para generar la imagen.

# %%
temperatura = np.random.rand(10, 10) * 100  # Temperaturas entre 0 y 100 °C
plt.imshow(temperatura, cmap='inferno')     # Mapa de color inferno (RGB)
plt.colorbar(label="Temperatura (°C)")
plt.title("Distribución de temperatura")
plt.show()

# %% [markdown]
# ## Tarea 1
# Generar un mapa de color personalizado a partir de un color hexadecimal base
#
# ### Instrucciones:
# 1. Define un color base en formato hexadecimal, por ejemplo `#66ccff` (azul claro).
# 2. Genera con numpy una matriz de valores aleatorios entre 0 y 1 (por ejemplo de 10x10).
# 3. Completa la función `darken_color` , que cumpla las siguientes caracteristicas:
#    - Reciba un valor entre 0 y 1.
#    - Devuelva un color más oscuro que el color base, en función del valor recibido.
#      * A mayor valor, más oscuro el color.
# 5. Aplica tu función a cada valor para obtener una matriz de colores personalizados.
# 6. Muestra la matriz de colores como una imagen (`imshow` de matplotlib), sin usar colormaps predefinidos.
# 7. Bonus: agrega una barra de color personalizada o una leyenda.
#
# ### Requisitos:
# - Trabajar con el formato de color hexadecimal.
# - No usar cmap de Matplotlib (se construye a mano).
# - Usar `matplotlib.colors.to_rgb` y `matplotlib.colors.to_hex` puede ayudarte.

# %%
# Paso 1: color base
# Define el color base
base_hex = "#8D0FF5"
base_rgb = np.array(mcolors.to_rgb(base_hex))
print(base_rgb)


#base rgb da una tupla de tres valores (a,b,c) o sea la representacion del base hex que elegi en rgb de valores entre 0 y 1
# Out:
# [0.55294118 0.05882353 0.96078431]

# %% [markdown]
# Que hace la función `to_rgb`?

# %%
# matriz de datos aleatorios
matriz= np.random.rand(10,10)
print(matriz)
# Out:
# [[0.29922294 0.19940937 0.66311628 0.21337812 0.74941061 0.87195358
#   0.63062959 0.12994128 0.3052022  0.51759543]
#  [0.05666214 0.96554559 0.59862356 0.76201542 0.93787787 0.88717794
#   0.30690658 0.13191671 0.98289091 0.95408907]
#  [0.30531006 0.70370992 0.50406583 0.37206109 0.07326192 0.56604602
#   0.87629801 0.55824612 0.19486471 0.52315258]
#  [0.38062499 0.42752098 0.53597271 0.72106682 0.09741262 0.24707857
#   0.37984281 0.17548456 0.19176813 0.86989322]
#  [0.38814577 0.54549869 0.30356828 0.72633867 0.91575207 0.29478288
#   0.07995989 0.09737535 0.97182329 0.96105719]
#  [0.79947087 0.59046296 0.97207891 0.637561   0.35057036 0.70267289
#   0.9822352  0.20973389 0.02945912 0.40953638]
#  [0.65433783 0.36445635 0.9411571  0.82347428 0.83032019 0.93635932
#   0.46874588 0.17505608 0.73513348 0.15188729]
#  [0.52502545 0.69230171 0.4487814  0.6500561  0.28636152 0.83779022
#   0.61964646 0.43836881 0.51243864 0.57356866]
#  [0.11398256 0.44425834 0.95056121 0.8591533  0.76928778 0.4932486
#   0.70739253 0.64821742 0.46845799 0.88536261]
#  [0.74797332 0.14347412 0.67247862 0.7158587  0.01506796 0.53897241
#   0.17525332 0.25362974 0.78563916 0.49785668]]

# %%
## Paso 3: funcion para oscurecer el color base
valor= random.uniform(0,1)
print(valor)

def darken_color(valor, base_rgb):
    darkened = tuple(channel*(1-valor) for channel in base_rgb)

    return mcolors.to_hex(darkened)
# Out:
# 0.5137667111382196

# %%
color_matrix = np.vectorize(lambda v: darken_color(v, base_rgb))(matriz)
color_matrix
# Out:
# array([['#630bac', '#710cc4', '#300553', '#6f0cc1', '#23043d', '#12021f',
#         '#34065a', '#7b0dd5', '#620aaa', '#440776'],
#        ['#850ee7', '#050108', '#390662', '#22043a', '#09010f', '#10021c',
#         '#620aaa', '#7a0dd5', '#020004', '#06010b'],
#        ['#620aaa', '#2a0449', '#46077a', '#59099a', '#830ee3', '#3d076a',
#         '#11021e', '#3e076c', '#720cc5', '#430775'],
#        ['#570998', '#51098c', '#410772', '#270444', '#7f0edd', '#6a0bb8',
#         '#570998', '#740cca', '#720cc6', '#120220'],
#        ['#560996', '#40076f', '#620aab', '#270443', '#0c0115', '#630bad',
#         '#820ee1', '#7f0edd', '#040007', '#05010a'],
#        ['#1c0331', '#3a0664', '#040007', '#330559', '#5c0a9f', '#2a0449',
#         '#030004', '#6f0cc2', '#890fee', '#530991'],
#        ['#310555', '#5a0a9c', '#08010e', '#19032b', '#18032a', '#090110',
#         '#4b0882', '#740cca', '#250441', '#780dd0'],
#        ['#430774', '#2b054b', '#4e0887', '#310556', '#650baf', '#170228',
#         '#36065d', '#4f088a', '#450777', '#3c0668'],
#        ['#7d0dd9', '#4e0888', '#07010c', '#140223', '#210339', '#47087c',
#         '#290448', '#320556', '#4b0882', '#10021c'],
#        ['#24043e', '#790dd2', '#2e0550', '#280446', '#8b0ff1', '#410771',
#         '#740cca', '#690bb7', '#1e0335', '#47087b']], dtype='<U7')

# %%
# Paso 4: generar imagen de colores
color_matrix = np.vectorize(lambda v: darken_color(v, base_rgb))(matriz)

# Paso 5: convertir a imagen RGB
rgb_matrix = np.array([[mcolors.to_rgb(color) for color in row] for row in color_matrix])

# Paso 6: mostrar
plt.imshow(rgb_matrix)
plt.title("Mapa de colores personalizados")
plt.axis('off')
plt.show()
